# %%
from yahoofinancials import YahooFinancials

# %%
stocks = ['EA', 'ISRG', 'MCHP', 'GD', 'LEN', 'EVRG', 'CAG', 'AOS', 'CCL', 'HES', 'PXD', 'CINF', 'AXP', 'PH', 'LH', 'SCHW', 'WBA', 'MKTX', 'NDSN', 'BEN', 'CI', 'EMR', 'CL', 'ECL', 'TTWO', 'EFX', 'FDX', 'INTU', 'HBAN', 'EIX', 'ABC', 'APD', 'SYF', 'EW', 'SHW', 'ADI', 'HSIC', 'PNR', 'MTB', 'PHM', 'WELL', 'CBOE', 'NLSN', 'PYPL', 'AVB', 'INTC', 'MMM', 'AKAM', 'XYL', 'AFL', 'SWK', 'NVDA', 'FLT', 'TAP', 'SEE', 'DUK', 'DOV', 'TYL', 'CTAS', 'NXPI', 'VLO', 'J', 'TROW', 'FFIV', 'TJX', 'JPM', 'GPC', 'CDNS', 'REG', 'ATVI', 'PFG', 'ICE', 'ANSS', 'DHR', 'TMUS', 'DLTR', 'EOG', 'ROST', 'CB', 'TSN', 'TRV', 'CTXS', 'KHC', 'DXCM', 'LUMN', 'DOW', 'TFC', 'CHTR', 'O', 'CME', 'TECH', 'BLK', 'JBHT', 'EPAM', 'RHI', 'UA', 'LUV', 'FRC', 'BKR', 'LYB', 'CE', 'DLR', 'TT', 'ESS', 'EBAY', 'TSCO', 'COO', 'PFE', 'DISH', 'GS', 'DVN', 'AEP', 'SWKS', 'NVR', 'MTD', 'KMX', 'AON', 'ALL', 'CDW', 'ODFL', 'COST', 'FITB', 'TXT', 'AAP', 'WEC', 'CHD', 'AJG', 'CLX', 'CARR', 'MPWR', 'EMN', 'KMB', 'ULTA', 'CAT', 'IR', 'KO', 'SEDG', 'NOC', 'AAPL', 'STZ', 'PCAR', 'UNP', 'EL', 'ETN', 'TER', 'AMD', 'C', 'VFC', 'WM', 'LDOS', 'POOL', 'XEL', 'PVH', 'NOW', 'LNT', 'TSLA', 'MDLZ', 'RF', 'GL', 'BLL', 'CVS', 'DD', 'ABBV', 'PAYC', 'CMS', 'WAB', 'IPG', 'PNC', 'ED', 'RMD', 'AMGN', 'ZBH', 'CFG', 'HOLX', 'DIS', 'CBRE', 'BSX', 'ENPH', 'BK', 'VRSK', 'ES', 'MRK', 'ABT', 'BRO', 'HWM', 'ZBRA', 'STE', 'UHS', 'VRTX', 'JNJ', 'DE', 'LNC', 'NTRS', 'CRL', 'ALLE', 'ADSK', 'NWSA', 'NEM', 'HUM', 'SPGI', 'NFLX', 'WAT', 'FBHS', 'XOM', 'UAA', 'MS', 'DRI', 'PNW', 'DVA', 'SBNY', 'GNRC', 'KR', 'WFC', 'MA', 'CMG', 'FMC', 'AME', 'UPS', 'SO', 'BR', 'GM', 'IPGP', 'FDS', 'FANG', 'PRU', 'FAST', 'PEG', 'ETSY', 'CNC', 'EXPE', 'STX', 'VZ', 'NTAP', 'MET', 'JNPR', 'TPR', 'AMCR', 'BDX', 'CTLT', 'SRE', 'NDAQ', 'CMA', 'COF', 'BAX', 'BWA', 'EXR', 'EQIX', 'ALGN', 'SPG', 'LMT', 'BXP', 'TDY', 'PKG', 'AVGO', 'SYY', 'FCX', 'EQR', 'NRG', 'HPE', 'CERN', 'CSX', 'DISCA', 'RTX', 'CMCSA', 'VTRS', 'FE', 'PEP', 'STT', 'PG', 'ADM', 'IRM', 'TGT', 'TMO', 'IVZ', 'PWR', 'HD', 'WMT', 'ROL', 'NEE', 'WY', 'GE', 'ADP', 'RJF', 'K', 'ITW', 'A', 'CHRW', 'DFS', 'DTE', 'GOOGL', 'FISV', 'SJM', 'MSFT', 'BBY', 'F', 'AMT', 'CTSH', 'PSA', 'EXPD', 'ROP', 'FOXA', 'DG', 'WRB', 'BMY', 'BKNG', 'WMB', 'MAR', 'WRK', 'DAL', 'FB', 'MLM', 'LKQ', 'MRNA', 'MDT', 'CMI', 'JCI', 'ANTM', 'REGN', 'ANET', 'APTV', 'GRMN', 'KMI', 'KLAC', 'QCOM', 'BIO', 'ALB', 'SNA', 'ATO', 'IP', 'PAYX', 'VNO', 'MU', 'AMP', 'AMAT', 'COP', 'GPN', 'AMZN', 'FTNT', 'PENN', 'DHI', 'LIN', 'HAL', 'PSX', 'OXY', 'HAS', 'SIVB', 'CSCO', 'HRL', 'JKHY', 'IBM', 'INFO', 'BIIB', 'CNP', 'MMC', 'L', 'IDXX', 'LLY', 'WHR', 'UNH', 'KEY', 'RCL', 'VTR', 'MHK', 'TWTR', 'CPRT', 'GLW', 'SNPS', 'PGR', 'DGX', 'AVY', 'EXC', 'GOOG', 'CTRA', 'KEYS', 'VMC', 'ILMN', 'OMC', 'PPL', 'NSC', 'CRM', 'GIS', 'AWK', 'MKC', 'NWL', 'GILD', 'CPB', 'TRMB', 'FIS', 'PEAK', 'QRVO', 'IFF', 'SLB', 'TEL', 'ZION', 'HSY', 'PTC', 'XRAY', 'IEX', 'FOX', 'AEE', 'SYK', 'MPC', 'CTVA', 'TXN', 'LW', 'HIG', 'T', 'DISCK', 'LHX', 'ROK', 'MNST', 'ACN', 'OKE', 'WST', 'CVX', 'USB', 'MAA', 'ARE', 'CCI', 'AIG', 'FTV', 'IT', 'URI', 'ABMD', 'NUE', 'GWW', 'HII', 'LRCX', 'PPG', 'RSG', 'NWS', 'PKI', 'MCO', 'PLD', 'D', 'APH', 'ETR', 'IQV', 'HON', 'ADBE', 'ZTS', 'TFX', 'NKE', 'DRE', 'BAC']
EBITDA = []
for i in stocks:
    yahoo_financials = YahooFinancials(i)
    a = yahoo_financials.get_key_statistics_data()
    print(i)
    EBITDA.append(a[i]["enterpriseToEbitda"])
# Out:
# EA
# ISRG
# MCHP
# GD
# LEN
# EVRG
# CAG
# AOS
# CCL
# HES
# PXD
# CINF
# AXP
# PH
# LH
# SCHW
# WBA
# MKTX
# NDSN
# BEN
# CI
# EMR
# CL
# ECL
# TTWO
# EFX
# FDX
# INTU
# HBAN
# EIX
# ABC
# APD
# SYF
# EW
# SHW
# ADI
# HSIC
# PNR
# MTB
# PHM
# WELL
# CBOE
# NLSN
# PYPL
# AVB
# INTC
# MMM
# AKAM
# XYL
# AFL
# SWK
# NVDA
# FLT
# TAP
# SEE
# DUK
# DOV
# TYL
# CTAS
# NXPI
# VLO
# J
# TROW
# FFIV
# TJX
# JPM
# GPC
# CDNS
# REG
# ATVI
# PFG
# ICE
# ANSS
# DHR
# TMUS
# DLTR
# EOG
# ROST
# CB
# TSN
# TRV
# CTXS
# KHC
# DXCM
# LUMN
# DOW
# TFC
# CHTR
# O
# CME
# TECH
# BLK
# JBHT
# EPAM
# RHI
# UA
# LUV
# FRC
# BKR
# LYB
# CE
# DLR
# TT
# ESS
# EBAY
# TSCO
# COO
# PFE
# DISH
# GS
# DVN
# AEP
# SWKS
# NVR
# MTD
# KMX
# AON
# ALL
# CDW
# ODFL
# COST
# FITB
# TXT
# AAP
# WEC
# CHD
# AJG
# CLX
# CARR
# MPWR
# EMN
# KMB
# ULTA
# CAT
# IR
# KO
# SEDG
# NOC
# AAPL
# STZ
# PCAR
# UNP
# EL
# ETN
# TER
# AMD
# C
# VFC
# WM
# LDOS
# POOL
# XEL
# PVH
# NOW
# LNT
# TSLA
# MDLZ
# RF
# GL
# BLL
# CVS
# DD
# ...

# %%
EBITDA
# Out:
# [26.805,
#  47.272,
#  17.114,
#  15.199,
#  6.071,
#  11.258,
#  12.549,
#  19.686,
#  -12.447,
#  10.581,
#  9.115,
#  5.887,
#  None,
#  13.719,
#  6.926,
#  None,
#  14.787,
#  35.292,
#  17.825,
#  6.445,
#  10.478,
#  15.908,
#  16.365,
#  26.718,
#  21.037,
#  24.524,
#  14.535,
#  60.327,
#  None,
#  10.469,
#  10.595,
#  18.852,
#  None,
#  38.778,
#  28.606,
#  33.122,
#  13.04,
#  13.703,
#  None,
#  6.68,
#  31.037,
#  15.074,
#  12.99,
#  42.578,
#  31.969,
#  6.028,
#  11.595,
#  17.414,
#  23.608,
#  7.639,
#  11.525,
#  74.268,
#  15.226,
#  7.724,
#  12.272,
#  13.043,
#  17.937,
#  64.311,
#  25.308,
#  19.586,
#  10.362,
#  13.862,
#  8.037,
#  25.898,
#  20.727,
#  None,
#  12.549,
#  52.783,
#  23.506,
#  13.486,
#  9.025,
#  20.967,
#  52.617,
#  20.522,
#  9.711,
#  15.199,
#  7.156,
#  12.366,
#  12.719,
#  6.749,
#  7.249,
#  27.324,
#  10.025,
#  109.228,
#  4.97,
#  5.853,
#  None,
#  10.281,
#  30.909,
#  28.089,
#  49.573,
#  18.433,
#  13.745,
# ...
